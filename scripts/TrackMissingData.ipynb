# %% [markdown]
# # Track Missing Data
# We need a system for efficiently identifying missing data, with our initial population being the set of all completed Mini Normal games. We also want to identify _why_ a data point is missing and, when a data point is incomplete, what is present and what isn't.
#
# ### What kinds of missing data are there?
# We can be missing setup/slot information, phase transition information, voting data, and/or thread content. And information can be missing because it hasn't been successfully extracted yet or because it's missing from the forum (e.g. because of a site crash). Also, rather than being present or missing, information can also instead be _inaccurate_ - but solving that problem requires an entirely different approach from that of detecting missing data, so we focus on it elsewhere. And finally, data can be undesirable - either because of a broken game (e.g. modflaking) or other issues that make inclusion in analysis difficult/unreasonable.
#
# ### How will we manage the prospect of missing data?
# We'll write a script that collects a list of existing completed game threads and checks our data set for associated data, building a list marking wherever data is missing. From there, we'll maintain this list, including updating it regularly as data collection ensues and new games finish, as well as manually marking instances where data collection is impossible or undesirable.

# %% [markdown]
# ## Dependencies

# %%
# dependences
import requests
import csv
import string
from lxml import html

# needed variables
no_punctuation = str.maketrans('', '', string.punctuation) # for quick removal of punctuation 
completed_url = 'https://forum.mafiascum.net/viewforum.php?f=53&start={}'

with open('../data/archive.txt') as f:
    archive = f.read()

# %% [markdown]
# ## Build List of Completed Games and Identify Those Missing from `archive.txt`
# For now we focus solely on Mini Normals. We probably don't need this cell anymore.

# %%
# start by finding number of threads in subforum
base = requests.get(completed_url.format(0)).content
topic_count = html.fromstring(base).xpath('//div[@class="pagination"]/text()')[0].strip()
topic_count = int(topic_count[:topic_count.find(' ')])

# scrape list of game urls and titles across each page of threads
game_urls, game_titles = [], []
for i in range(0, topic_count, 100):
    page = requests.get(completed_url.format(i)).content
    
    # game titles
    titles = html.fromstring(page).xpath("//div[@class='forumbg']//dt/a/text()")
    game_titles += [title.strip() for index, title in enumerate(titles) if index % 2 == 0]
    
    # game urls
    urls = html.fromstring(page).xpath("//div[@class='forumbg']//dt/a/@href")
    game_urls += [url[1:url.find('&sid')] for index, url in enumerate(urls) if index % 2 == 0]

# mark which of these aren't in archive
excluded = []
for index, url in enumerate(game_urls):
    count = archive.count(url[1:] + '\n')
    if count == 0 :
        excluded.append(index)
    
# print counts
print('Number of URLs:', len(game_urls))
print('Number of URLs Unmatched to String in Archive:', len(excluded))
print('Number of Games in Archive:', len(archive.split('\n\n\n')))
print('{} threads unaccounted for!'.format(len(game_urls) - len(excluded) - len(archive.split('\n\n\n'))))
print('Number of URLs After Excluding Duplicates:', len(list(set(game_urls))))
print()
# Out:
# Number of URLs: 1025
# Number of URLs Unmatched to String in Archive: 727
# Number of Games in Archive: 298
# 0 threads unaccounted for!
# Number of URLs After Excluding Duplicates: 1023

# %% [markdown]
# ## Identify and Count Games Included in transitions.tsv
# First entry of each row has the game number. Storing this instead of URL was a bad idea, as now I have to write code to match game numbers with URLs. Along with checking if a row associated w/ a game exists, I have to check if the row is complete - this means no entry in the row has a question mark and the last entry is a hyphen. My goal for this project today is to achieve that for every game in my initial ~322 game data set - or mark games where this isn't possible for some reason.

# %%
# build list of game numbers from archive
numbers = []
for game in archive.split('\n\n\n'):
    name = game.split('\n')[1]
    
    print(name)
    print([int(i) for i in name.translate(str.maketrans('', '', string.punctuation)).split() if i.isdigit()])

assert False

# load transitions csv 
count = 0
with open('../data/transitions.tsv') as f:
    transitions = csv.reader(f, delimiter='\t')
    for row in transitions:
        # print(row)
        
        count += 1
        if count > 10:
            assert False
# Out:
# Game 1091: Mafia Mania
# [1091]
# Game 1094: Mariposa Peak Mafia
# [1094]
# Game 1098: The Mafia Experiment!
# [1098]
# Game 1101: Suspiciously Normal Mafia
# [1101]
# Game 1102: Rivertown Mafia
# [1102]
# Game 1105: A Mafia Invasion!
# [1105]
# Game 1107: Just a Game
# [1107]
# Game 1112: Mundania
# [1112]
# Game 1114: Jim's Mafia
# [1114]
# Game 1117: Manhattan Special
# [1117]
# Game 1121: Nexusville Mafia
# [1121]
# Game 1122: Mafia.Exe
# [1122]
# Game 1126: Averagely Suspicious Mafia
# [1126]
# Game 1130: A Fishbowl Invasion by Ninja Monkeys!
# [1130]
# Game 1133: Mafia in Venice
# [1133]
# Game 1137: Long Overdue Mafia
# [1137]
# Game 1140: Mafia Mishmash
# [1140]
# Game 1142: Quintessentially English Mafia
# [1142]
# Game 1145: Plain Mafia
# [1145]
# Game 1146: Don't Get Slapped in the Face by a Fish Mafia
# [1146]
# Game 1147: Royal Mafia at the Round Table
# [1147]
# Game 1152
# [1152]
# Game 1156
# [1156]
# Game 1157: Witch-Hunt Nightless
# [1157]
# Game 1159: Powerrox93's Mini Normal I
# [1159]
# Game 1161: Neruzian Era Mafia
# [1161]
# Game 1164: 9p normal mafia.
# [1164]
# Game 1166: Town Hall Mafia
# [1166]
# Game 1170: Nowhereville Mafia '11
# [1170]
# Game 1175: Iowa Mafia
# [1175]
# Game 1177: Normal Game
# [1177]
# Game 1180
# [1180]
# Game 1183: Mafiamatical Mathia
# [1183]
# Game 1187
# [1187]
# Game 1190: A Day in the Life
# [1190]
# Game 1193: Hacker's Panic mafia
# [1193]
# Game 1195: The Beehive Mystery
# [1195]
# Game 1199: Plissken's Pit
# [1199]
# Game 1202: Smalltown Mafia
# [1202]
# Game 1203: Set's Speed Mafia
# [1203]
# Game 1204: Generic Mafia
# [1204]
# Game 1205: Tough Guy Mafia
# [1205]
# Game 1207: LIPD Mafia
# [1207]
# Game 1211: Murder in Sicily
# [1211]
# Game 1216: S.M.H. (A.S.N.P.T.) Mafia
# [1216]
# Game 1221: Vegas Mafia
# [1221]
# Game 1227: Small Town Scumbags
# [1227]
# Game 1230: Xylbot is Normal I Swear
# [1230]
# Game 1231: 8p Swift
# [1231]
# Game 1234: Masquerade Mafia
# [1234]
# Game 1236: Classic Mafia
# [1236]
# Game 1238: One After the Other
# [1238]
# Game 1241: Lab Mafia
# [1241]
# Game 1317
# [1317]
# Game 1318: This Little Town
# [1318]
# Game 1321: Anxiety's Alliteration Mafia
# [1321]
# Game 1323: Mafia on the BEACH
# [1323]
# Game 1326: Mansion Mafia
# [1326]
# Game 1332: A Not So Normal Village
# [1332]
# Game 1333: Terror in the Parlor
# [1333]
# Game 1337: Elite Mafia
# [1337]
# Game 1338: Cyborgian Reenactment Mafia
# [1338]
# Game 1340
# [1340]
# Game 1341
# [1341]
# Game 1343: The Murder of Papa Zito
# [1343]
# Game 1345
# [1345]
# Game 1346: Flavorless Mafia
# [1346]
# Game 1347
# [1347]
# Game 1351
# [1351]
# Game 1352: Leprechaun Mafia
# [1352]
# Game 1354: Vedere le Viste!
# [1354]
# Game 1357
# [1357]
# Game 1359: A Death Already Died
# [1359]
# Game 1360
# [1360]
# Game 1361: Rainy Days Mafia
# [1361]
# Game 1365: Generic Village Mafia
# [1365]
# Game 1368
# [1368]
# Game 1372
# [1372]
# Game 1373: Oh My!
# [1373]
# Game 1375
# [1375]
# Game 1376: Mafia By the River
# [1376]
# Game 1379
# [1379]
# Game 1382: The Mystery at Village Lake
# [1382]
# Game 1385: Thirsty Souls Mafia
# [1385]
# Game 1387: Mafia in Corteleona
# [1387]
# Game 1390
# [1390]
# Game 1393
# [1393]
# Game 1394
# [1394]
# Game 1398
# [1398]
# Game 1400: Bubble Tape Mafia
# [1400]
# Game 1401: Turn of the Century!
# [1401]
# Game 1407
# [1407]
# Game 1408: Playing with Fire
# [1408]
# Game 1410: Mafia in the Unknown
# [1410]
# Game 1412: 0 Percent Flavor Mafia
# [1412, 0]
# Game 1414: Mafia and Werewolves
# [1414]
# Game 1420: The Beginning of the End
# [1420]
# Game 1422: White Room Mafia
# [1422]
# Game 1424: Mafibleh
# [1424]
# Game 1426: Hell's Bottom
# [1426]
# Game 1429: Hunt in the Dungeon
# [1429]
# Game 1433: State Farm Mafia
# [1433]
# Game 1439
# [1439]
# Game 1440: Unoriginal Mafia
# [1440]
# Game 1444: Mafia in the Park
# [1444]
# Game 1445: Overly Cheerful Moderator Mafia
# [1445]
# Game 1446: Generic Mafia
# [1446]
# Game 1449: Ordinary Town
# [1449]
# Game 1452: Inevitable Mafia
# [1452]
# Game 1454
# [1454]
# Game 1456: Revenge
# [1456]
# Game 1457: Gorilla Glue
# [1457]
# Game 1458: Don't Feed the Bears
# [1458]
# Game 1460: Normalville Mafia
# [1460]
# Game 1462: Serra's Fun House
# [1462]
# Game 1463
# [1463]
# Game 1464
# [1464]
# Game 1469: Rage
# [1469]
# Game 1471: Rural Mafia
# [1471]
# Game 1472: welcome 2 #SWAGTOWN w. ur boy empire
# [1472, 2]
# Game 1474: Desperado's Revenge
# [1474]
# Game 1481: ETL's Horrific Camping Trip
# [1481]
# Game 1483: Finagling of Flitter Hills
# [1483]
# Game 1486: Fruit Basket Mafia
# [1486]
# Game 1493: Lucky's <insert cool name here> game
# [1493]
# Game 1494: A Murder in Murderville
# [1494]
# Game 1496: The Cash Cabd
# [1496]
# Game 1499: State Farm Mafia 2
# [1499, 2]
# Game 1501: We're On A Boat
# [1501]
# Game 1505: N is for Normal
# [1505]
# Mini 1509 - Marriage in Mafiatown
# [1509]
# Mini 1511: Insurgency Emergency
# [1511]
# Mini 1514: ETL's Royal Council
# [1514]
# Mini 1516: Mafia in Space
# [1516]
# Mini 1517 - The Sun Sets on Duskville
# [1517]
# Mini 1521: The Fall
# [1521]
# Mini 1527 - The Darkness Within
# [1527]
# Mini 1530 - Guyett's Paranoid Geology Trip
# [1530]
# Mini 1532: Mac's Mini Normal
# [1532]
# Mini 1535
# [1535]
# Mini 1540 - Terror in Eagleland
# [1540]
# Mini 1541: The Heart of Artificial Reality
# [1541]
# Mini 1543--Natirasha's On Parole!
# []
# Mini 1544: Dry, Bland and Tasteless
# [1544]
# Mini: 1553 Gone jeeping
# [1553]
# Mini 1556: Greetings Without Spain
# [1556]
# Mini 1559: The 80s!
# [1559]
# Mini 1560 - Reck's Walk of Shame
# [1560]
# Mini 1564 - Nyctapolis
# [1564]
# Mini 1569: The Golden Cookie Heist!
# [1569]
# Mini 1570: North Sea Winter's Bite
# [1570]
# Mini 1574: Mountainous Mafia with Daytalk
# [1574]
# Mini 1575: Mafia on the Metro
# [1575]
# Mini 1579: The Great Flavor Caper
# [1579]
# Mini 1582: Formerfish's First Foray
# [1582]
# Mini 1584: Neuroscience Mafia
# [1584]
# Mini 1585: Muskoka Murder Mystery
# [1585]
# Mini 1587: Mutiny!
# [1587]
# Mini 1589: The Train of Death
# [1589]
# Mini 1590: Brian's Flavorless Mini
# [1590]
# Mini 1591: PFs Flavorless Normal
# [1591]
# Mini 1596: Minimence I
# [1596]
# Mini 1600: Fuzzy First Forray
# [1600]
# Mini 1602
# [1602]
# Mini 1606: Whodunit? Mafia
# [1606]
# Mini Normal 1609: The Case Of Doctor Pepper
# [1609]
# Mini 1618: Profia
# [1618]
# Mini 1620 â€” The Mod is Using Comic Sans
# [1620]
# Mini 1623
# [1623]
# Mini 1625: Redemption
# [1625]
# Mini 1627: Ninja Mini Mafia
# [1627]
# Mini 1632 - Zar's Holiday Bash - Mardi Gras Showdown
# [1632]
# Mini 1636: Mafialand Mayhem!
# [1636]
# Mini 1642: The Burning
# [1642]
# Mini 1645: BooneyToonz I - The Creepy Caravansary
# [1645]
# Mini #1647: Eine Kleine Nacht-Mord
# []
# Mini 1648: Mafia in the Noose Factory.
# [1648]
# Mini 1651: One Flew Over The Monkey's Nest
# [1651]
# Mini 1652: Sweet Dreams
# [1652]
# Mini 1653: A Game of Pokes
# [1653]
# Mini 1655: Delicious Mafia
# [1655]
# Mini Normal 1658: Classic Rock Mafia
# [1658]
# Mini 1660 - TTH's Mini Normal
# [1660]
# mini 1662: Paint the village red
# [1662]
# Mini 1666: The Reds
# [1666]
# Mini 1668 - Mafia in Bremen
# [1668]
# Mini 1669 - Pictures for Sad Children Mafia
# [1669]
# Mini 1671 - Eclipse Mafia
# [1671]
# Mini 1674: A Minimalist Text Adventure
# [1674]
# Mini 1680
# [1680]
# Mini 1685: BooneyToonz II - Looney Tunes
# [1685]
# Mini 1687: Refraction Mafia
# [1687]
# MINI 1688 â€” BEES!!!
# [1688]
# Mini 1689: Rhyme & Reason
# [1689]
# Mini 1690 - Zed's Tavern!
# [1690]
# Mini Normal 1692 â€“ A Crack In Time?
# [1692]
# Mini 1697 - a Re-balanced Game of Mafia
# [1697]
# Mini 1698: MDCXCVIII
# [1698]
# Mini 1699 - #swag wars: THE empire strikes back
# [1699]
# Mini 1700: Space Mafia
# [1700]
# Mini 1701 - Modified Werewolf 13er
# [1701]
# Mini 1703: Mafia on the Run
# [1703]
# Mini 1705
# [1705]
# Mini 1706 - Pula Mafia
# [1706]
# Mini Normal 1707 - Frog Mafia!
# [1707]
# Mini 1708: Mafia CafÃ©
# [1708]
# Mini 1709: Radjarok
# [1709]
# Mini Normal 1711: Flavor not required.
# [1711]
# Mini-Normal 1713: Mystery Mansion Mafia
# [1713]
# Mini 1715 - Z
# [1715]
# Mini Normal 1716 - Flavourless Mafia
# [1716]
# Mini Normal 1719 - Flavorless Fun!
# [1719]
# Mini 1720 Number Mafia
# [1720]
# MINI 1721
# [1721]
# Mini 1725
# [1725]
# Mini 1728: Circus Mafia
# [1728]
# Mini 1733: Jurassic Monkey
# [1733]
# Mini 1735: Radjarok 2
# [1735, 2]
# Mini 1742: Danish Blue
# [1742]
# Mini Normal 1744 - Country Music Mafia
# [1744]
# Mini 1747: Cinnamon Roll Mafia
# [1747]
# Mini 1749: Classic Rock Mafia
# [1749]
# Mini 1752: Back to December
# [1752]
# Mini 1755
# [1755]
# Mini 1757
# [1757]
# Mini 1761: Red Neighborhood
# [1761]
# Mini 1762
# [1762]
# Mini Normal 1763
# [1763]
# Mini 1769: Ice Cream Mafia
# [1769]
# Mini 1772
# [1772]
# Mini 1773 : Symphonic Metal Mafia
# [1773]
# Mini 1777: Varied Music Mafia
# [1777]
# Mini 1779 - Werewolves of Wildwood Grove
# [1779]
# Mini 1782
# [1782]
# Mini 1786: Inspirational Mafia
# [1786]
# Mini 1787: Peruvian Nightclub Mafia
# [1787]
# Mini 1789: Puppy Mafia!
# [1789]
# Mini 1791: Mildly Dangerous Mafia
# [1791]
# Mini 1794: Gunslingers Ahoy!
# [1794]
# Mini Normal 1797 Probably Not Actually Normal Mafia
# [1797]
# Mini 1800
# [1800]
# Mini 1805
# [1805]
# Mini Normal 1809
# [1809]
# Mini 1811
# [1811]
# Mini 1812 | Quolls
# [1812]
# Mini Normal 1814 Machiavellian Mafia
# [1814]
# Mini 1820 â€” Lazy Summer Mafia
# [1820]
# Mini Normal 1823
# [1823]
# Mini Normal 1825
# [1825]
# Mini Normal 1827 - No Flavor Mafia
# [1827]
# Mini Normal 1829
# [1829]
# Mini 1830
# [1830]
# Mini Normal 1832
# [1832]
# Mini Normal 1833
# [1833]
# Mini 1836: Space Mafia
# [1836]
# Mini 1838
# [1838]
# Mini 1839
# [1839]
# Mini 1841
# [1841]
# Mini 1843
# [1843]
# Mini Normal 1844
# [1844]
# Mini 1847
# [1847]
# Mini Normal 1848
# [1848]
# Mini Normal 1850-The Penguin Mafia
# []
# Mini 1854
# [1854]
# Mini 1857
# [1857]
# Mini 1860
# [1860]
# Mini 1861: Musical Mafia
# [1861]
# Mini 1862
# [1862]
# Mini 1866: Landmark Mafia
# [1866]
# Mini 1870
# [1870]
# Mini 1873
# [1873]
# Mini 1874: Camping Trip Mafia
# [1874]
# Mini 1875: Pine's Death Trap
# [1875]
# Mini 1879: Bringer Mafia II
# [1879]
# Mini 1883
# [1883]
# Mini 1888 - TwoFace Mafia
# [1888]
# Mini 1890
# [1890]
# Mini 1892
# [1892]
# Mini 1893
# [1893]
# Mini 1895
# [1895]
# Mini 1897
# [1897]
# Mini 1900
# [1900]
# Mini 1903
# [1903]
# Mini 1905
# [1905]
# Mini Normal 1908
# [1908]
# Mini Normal 1909
# [1909]
# Mini Normal 1911
# [1911]
# Mini Normal 1914
# [1914]
# Mini Normal 1917
# [1917]
# Mini Normal 1919
# [1919]
# Mini Normal 1920
# [1920]
# Mini Normal 1921
# [1921]
# Mini Normal 1923
# [1923]
# Mini Normal 1925
# [1925]
# Mini Normal 1929
# [1929]
# Mini Normal 1931
# [1931]
# Mini Normal 1933
# [1933]
# Mini Normal 1938
# [1938]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-7-15c9b24b68dd> in <module>
#       7     print([int(i) for i in name.replace(':', '').split() if i.isdigit()])
#       8
# ----> 9 assert False
#      10
#      11 # load transitions csv
#
# AssertionError:
